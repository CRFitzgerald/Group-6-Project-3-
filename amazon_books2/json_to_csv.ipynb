# %%
# Import dependencies
import pandas as pd

# %%
# Read JSON file
df = pd.read_json("top_100_books.json")

# %%
df
# Out:
#                                                 image  \
# 0   https://m.media-amazon.com/images/I/71ok9jCkgV...
# 1   https://m.media-amazon.com/images/I/91HwoNG6iq...
# 2   https://m.media-amazon.com/images/I/91bS0lS-JU...
# 3   https://m.media-amazon.com/images/I/91jbLYiK43...
# 4   https://m.media-amazon.com/images/I/617uZq23IP...
# ..                                                ...
# 95  https://m.media-amazon.com/images/I/81HeVWjFY7...
# 96  https://m.media-amazon.com/images/W/IMAGERENDE...
# 97  https://m.media-amazon.com/images/W/IMAGERENDE...
# 98  https://m.media-amazon.com/images/W/IMAGERENDE...
# 99  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                             title  \
# 0                   Lessons in Chemistry: A Novel
# 1   Tomorrow, and Tomorrow, and Tomorrow: A novel
# 2                       Demon Copperhead: A Novel
# 3            Remarkably Bright Creatures: A Novel
# 4                       Reminders of Him: A Novel
# ...

# %%
# Save dataframe to csv
df.to_csv('top_100_books.csv')
