# %%
import pymongo
import pprint

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["amazon_db"]
collection = db["books_collection"]

# %%
cursor = collection.find()
for document in cursor:
    pprint.pprint(document)
# Out:
# {'_id': ObjectId('642777dffae5a69279b83fd2'),
#  'author': 'Jodi Picoult, Jennifer Finney Boylan, et al.',
#  'image': 'https://m.media-amazon.com/images/I/91fas7WZMNL._AC_UY218_.jpg',
#  'prices': {'Audio': '$37.67',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.99',
#             'Kindle': '$14.99',
#             'Paperback': '$34.74'},
#  'product_link': '/Audible-Mad-Honey-A-Novel/dp/B09QQV1YJJ/ref=sr_1_6?qid=1680261196&sr=8-6&srs=17296221011',
#  'publish_date': 'October 4, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#31 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#3 in Fiction Sagas',
#              '#4 in Family Saga Fiction',
#              "#7 in Women's Fiction (Audible Books & Originals)"],
#  'rating': '4.4',
#  'rating_breakdown': ['2', '2', '8', '27', '60'],
#  'review_count': '22,581',
#  'title': 'Mad Honey: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fd3'),
#  'author': 'Barbara Kingsolver, Charlie Thurston, et al.',
#  'image': 'https://m.media-amazon.com/images/I/91bS0lS-JUL._AC_UY218_.jpg',
#  'prices': {'Audio': '$41.57',
#             'Audiobook': '$0.00',
#             'Hardcover': '$19.50',
#             'Kindle': '$15.99',
#             'Paperback': '$31.05'},
#  'product_link': '/Audible-Demon-Copperhead-A-Novel/dp/B09QH6C42C/ref=sr_1_3?qid=1680261196&sr=8-3&srs=17296221011',
#  'publish_date': 'October 18, 2022',
#  'publisher': 'HarperAudio',
#  'ranking': ['#19 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#1 in Small Town & Rural Fiction (Audible Books & Originals)',
#              '#1 in Coming of Age Fiction (Audible Books & Originals)',
#              '#1 in Small Town & Rural Fiction (Books)'],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '2', '5', '18', '74'],
#  'review_count': '28,124',
#  'title': 'Demon Copperhead: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fd4'),
#  'author': 'Colleen Hoover  | Jan 18, 2022',
#  'image': 'https://m.media-amazon.com/images/I/617uZq23IPL._AC_UY218_.jpg',
#  'prices': {'Audio': '$14.99',
#             'Audiobook': '$0.00',
#             'Kindle': '$0.00',
#             'Library': '$37.78',
#             'Paperback': '$9.57'},
#  'product_link': '/Reminders-Him-Novel-Colleen-Hoover/dp/1542025605/ref=sr_1_5?qid=1680261196&sr=8-5&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': '',
#  'ranking': [],
#  'rating': '4.7',
#  'rating_breakdown': ['1', '1', '4', '16', '78'],
#  'review_count': '207,191',
#  'title': 'Reminders of Him: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fd5'),
#  'author': 'Geraldine Brooks  | Jun 14, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81P0W3YcvXL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$22.99',
#             'Kindle': '$13.99',
#             'Paperback': '$26.99'},
#  'product_link': '/Horse-Novel-Geraldine-Brooks-ebook/dp/B09G9D94VW/ref=sr_1_7?qid=1680261196&sr=8-7&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Viking',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['2', '2', '5', '20', '71'],
#  'review_count': '21,133',
#  'title': 'Horse: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fd6'),
#  'author': 'Jennette McCurdy and Simon & Schuster Audio',
#  'image': 'https://m.media-amazon.com/images/I/71Dax2X6RhL._AC_UY218_.jpg',
#  'prices': {'Audio': '$30.32',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.94',
#             'Kindle': '$14.99',
#             'Paperback': '$28.97'},
#  'product_link': '/Im-Glad-My-Mom-Died/dp/B09VHWC5YK/ref=sr_1_8?qid=1680261196&sr=8-8&srs=17296221011',
#  'publish_date': 'August 9, 2022',
#  'publisher': 'Simon & Schuster Audio',
#  'ranking': ['#18 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#1 in Dysfunctional Families (Audible Books & Originals)',
#              '#1 in Dysfunctional Families (Books)',
#              '#1 in Relationships (Audible Books & Originals)'],
#  'rating': '4.7',
#  'rating_breakdown': ['1', '1', '4', '15', '80'],
#  'review_count': '46,267',
#  'title': "I'm Glad My Mom Died"}
# {'_id': ObjectId('642777dffae5a69279b83fd7'),
#  'author': 'Bonnie Garmus, Miranda Raison, et al.',
#  'image': 'https://m.media-amazon.com/images/I/71ok9jCkgVL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$17.99',
#             'Kindle': '$14.99',
#             'Paperback': '$27.90',
#             'Spiral-bound': '$37.81'},
#  'product_link': '/Lessons-in-Chemistry-A-Novel/dp/B09BBK79VB/ref=sr_1_1?qid=1680261196&sr=8-1&srs=17296221011',
#  'publish_date': 'April 5, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#5 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#1 in Historical Fiction (Books)',
#              '#1 in Historical Fiction (Audible Books & Originals)',
#              '#1 in Humorous Fiction'],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '6', '20', '72'],
#  'review_count': '126,226',
#  'title': 'Lessons in Chemistry: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fd8'),
#  'author': 'Yung Pueblo  | Oct 4, 2022',
#  'image': 'https://m.media-amazon.com/images/I/91lgm-V5fqL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$15.88',
#             'Kindle': '$13.99',
#             'Paperback': '$35.30',
#             'Spiral-bound': '$31.96'},
#  'product_link': '/Lighter-Connect-Present-Expand-Future/dp/0593233174/ref=sr_1_10?qid=1680261196&sr=8-10&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Harmony',
#  'ranking': [],
#  'rating': '4.7',
#  'rating_breakdown': ['2', '2', '4', '10', '82'],
#  'review_count': '1,330',
#  'title': 'Lighter: Let Go of the Past, Connect with the Present, and Expand '
#           'the Future'}
# {'_id': ObjectId('642777dffae5a69279b83fd9'),
#  'author': 'Stephen King, Seth Numrich, et al.',
#  'image': 'https://m.media-amazon.com/images/I/91tQkOHvW9L._AC_UY218_.jpg',
#  'prices': {'Audio': '$61.52',
#             'Audiobook': '$0.00',
#             'Hardcover': '$16.25',
#             'Kindle': '$16.99',
#             'Paperback': '$18.00'},
#  'product_link': '/Audible-Fairy-Tale/dp/B09R5ZPY6Y/ref=sr_1_9?qid=1680261196&sr=8-9&srs=17296221011',
#  'publish_date': 'September 6, 2022',
#  'publisher': 'Simon & Schuster Audio',
#  'ranking': ['#25 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#1 in Supernatural Thrillers (Books)',
#              '#1 in Supernatural Thrillers (Audible Books & Originals)',
#              '#2 in Fantasy (Audible Books & Originals)'],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '2', '6', '18', '74'],
#  'review_count': '41,441',
#  'title': 'Fairy Tale'}
# {'_id': ObjectId('642777dffae5a69279b83fda'),
#  'author': 'Gabrielle Zevin  | Jul 5, 2022',
#  'image': 'https://m.media-amazon.com/images/I/91HwoNG6iqL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$15.49',
#             'Kindle': '$13.99',
#             'Paperback': '$25.49'},
#  'product_link': '/Tomorrow-novel-Gabrielle-Zevin-ebook/dp/B09JBCGQB8/ref=sr_1_2?qid=1680261196&sr=8-2&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Knopf',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['1', '2', '10', '28', '59'],
#  'review_count': '38,021',
#  'title': 'Tomorrow, and Tomorrow, and Tomorrow: A novel'}
# {'_id': ObjectId('642777dffae5a69279b83fdb'),
#  'author': 'Celeste Ng  | Oct 4, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81xQjuzayAL._AC_UY218_.jpg',
#  'prices': {'Audio': '$30.06',
#             'Audiobook': '$0.00',
#             'Hardcover': '$15.19',
#             'Kindle': '$14.99',
#             'Paperback': '$21.49'},
#  'product_link': '/Our-Missing-Hearts-Celeste-Ng-ebook/dp/B09QBYCC3J/ref=sr_1_12?qid=1680261196&sr=8-12&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Penguin Press',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['2', '4', '13', '28', '53'],
#  'review_count': '12,135',
#  'title': 'Our Missing Hearts: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fdc'),
#  'author': 'Ed Yong and Random House Audio',
#  'image': 'https://m.media-amazon.com/images/I/81iRK9qPcML._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$24.99',
#             'Kindle': '$13.99',
#             'Paperback': '$25.00'},
#  'product_link': '/Immense-World-Animal-Senses-Reveal/dp/B09LFLMXF2/ref=sr_1_13?qid=1680261196&sr=8-13&srs=17296221011',
#  'publish_date': 'June 21, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#784 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#1 in Zoology (Books)',
#              '#2 in Natural History (Books)',
#              '#2 in Animals (Audible Books & Originals)'],
#  'rating': '4.7',
#  'rating_breakdown': ['1', '1', '3', '14', '81'],
#  'review_count': '2,175',
#  'title': 'An Immense World: How Animal Senses Reveal the Hidden Realms Around '
#           'Us'}
# {'_id': ObjectId('642777dffae5a69279b83fdd'),
#  'author': "Maggie O'Farrell  | Sep 6, 2022",
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/91fTEzD2QOL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$18.78',
#             'Kindle': '$14.99',
#             'Paperback': '$15.30'},
#  'product_link': '/Marriage-Portrait-novel-Maggie-OFarrell-ebook/dp/B09RTYQW2S/ref=sr_1_17?qid=1680261260&sr=8-17&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Knopf',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['2', '3', '13', '31', '51'],
#  'review_count': '14,119',
#  'title': 'The Marriage Portrait: A novel'}
# {'_id': ObjectId('642777dffae5a69279b83fde'),
#  'author': 'Susan Cain  | Apr 5, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/81d3qLZSKlL._AC_UY218_.jpg',
#  'prices': {'Audio': '$24.98',
#             'Audiobook': '$0.00',
#             'Hardcover': '$14.63',
#             'Kindle': '$15.99',
#             'Paperback': '$18.00'},
#  'product_link': '/Bittersweet-Sorrow-Longing-Make-Whole/dp/0451499786/ref=sr_1_18?qid=1680261260&sr=8-18&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Crown',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['2', '2', '8', '17', '71'],
#  'review_count': '1,360',
#  'title': "Bittersweet (Oprah's Book Club): How Sorrow and Longing Make Us "
#           'Whole'}
# {'_id': ObjectId('642777dffae5a69279b83fdf'),
#  'author': 'Jon Meacham and Random House Audio',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/71lP-utff4L._AC_UY218_.jpg',
#  'prices': {'Audio': '$33.75',
#             'Audiobook': '$0.00',
#             'Hardcover': '$20.23',
#             'Kindle': '$14.99',
#             'Paperback': '$38.46'},
#  'product_link': '/There-Was-Light-American-Struggle/dp/B09W34B832/ref=sr_1_19?qid=1680261260&sr=8-19&srs=17296221011',
#  'publish_date': 'October 18, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#667 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#1 in American Civil War',
#              '#1 in American Civil War Biographies (Books)',
#              '#1 in U.S. Civil War History'],
#  'rating': '4.7',
#  'rating_breakdown': ['2', '1', '4', '10', '83'],
#  'review_count': '1,323',
#  'title': 'And There Was Light: Abraham Lincoln and the American Struggle'}
# {'_id': ObjectId('642777dffae5a69279b83fe0'),
#  'author': 'Matthew Perry and Macmillan Audio',
#  'image': 'https://m.media-amazon.com/images/I/81Js8wlvnDL._AC_UY218_.jpg',
#  'prices': {'Audio': '$23.99',
#             'Audiobook': '$0.00',
#             'Hardcover': '$15.67',
#             'Kindle': '$14.99',
#             'Paperback': '$25.46'},
#  'product_link': '/Friends-Lovers-Big-Terrible-Thing/dp/B09RQ4L751/ref=sr_1_16?qid=1680261196&sr=8-16&srs=17296221011',
#  'publish_date': 'November 1, 2022',
#  'publisher': 'Macmillan Audio',
#  'ranking': ['#111 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#1 in Television Performer Biographies',
#              '#1 in Film & TV',
#              '#3 in Actor & Entertainer Biographies'],
#  'rating': '4.4',
#  'rating_breakdown': ['2', '3', '10', '21', '64'],
#  'review_count': '18,437',
#  'title': 'Friends, Lovers, and the Big Terrible Thing: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b83fe1'),
#  'author': 'Bono and Random House Audio',
#  'image': 'https://m.media-amazon.com/images/I/910-EtZIYKL._AC_UY218_.jpg',
#  'prices': {'Audio': '—',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.79',
#             'Kindle': '$14.99',
#             'Paperback': '—'},
#  'product_link': '/Surrender-40-Songs-One-Story/dp/B09ZK1XJ4X/ref=sr_1_14?qid=1680261196&sr=8-14&srs=17296221011',
#  'publish_date': 'November 1, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#302 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#1 in Social Activist Biographies',
#              '#1 in Biographies of Activists',
#              '#2 in Composer & Musician Biographies'],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '2', '5', '15', '76'],
#  'review_count': '2,049',
#  'title': 'Surrender: 40 Songs, One Story'}
# {'_id': ObjectId('642777dffae5a69279b83fe2'),
#  'author': 'Taylor Jenkins Reid  | Aug 30, 2022',
#  'image': 'https://m.media-amazon.com/images/I/A1qnlFuEGtL._AC_UY218_.jpg',
#  'prices': {'Audio': '$32.04',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.98',
#             'Kindle': '$13.99',
#             'Paperback': '$18.00'},
#  'product_link': '/Carrie-Soto-Back-Taylor-Jenkins-ebook/dp/B09SNYDGR9/ref=sr_1_15?qid=1680261196&sr=8-15&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Ballantine Books',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['1', '2', '9', '31', '57'],
#  'review_count': '20,688',
#  'title': 'Carrie Soto Is Back: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fe3'),
#  'author': 'Emily St. John Mandel  | Apr 5, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/81Xs3j5UqAL._AC_UY218_.jpg',
#  'prices': {'Audio': '$32.95',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.00',
#             'Kindle': '$11.99',
#             'Paperback': '$15.30'},
#  'product_link': '/Sea-Tranquility-Emily-John-Mandel-ebook/dp/B099DRHTLX/ref=sr_1_23?qid=1680261260&sr=8-23&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Vintage',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '3', '12', '32', '52'],
#  'review_count': '19,443',
#  'title': 'Sea of Tranquility: A novel'}
# {'_id': ObjectId('642777dffae5a69279b83fe4'),
#  'author': 'Javier Zamora and Random House Audio',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/71T0UeyDv6L._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$23.75',
#             'Kindle': '$13.99',
#             'Paperback': '$16.20'},
#  'product_link': '/Audible-Solito-Alone-A-Memoir/dp/B09SJ4XFCT/ref=sr_1_22?qid=1680261260&sr=8-22&srs=17296221011',
#  'publish_date': 'September 6, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#1,114 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#1 in Hispanic & Latin Biographies',
#              '#2 in Emigration & Immigration Studies (Audible Books & '
#              'Originals)',
#              '#2 in Emigration & Immigration Studies (Books)'],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '5', '17', '75'],
#  'review_count': '3,477',
#  'title': 'Solito: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b83fe5'),
#  'author': 'Part of: What If? (2 books)   |  Randall Munroe  | Sep 13, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/71xD1Mog4AL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$18.57',
#             'Kindle': '$15.99',
#             'Paperback': '$19.00'},
#  'product_link': '/What-Additional-Scientific-Hypothetical-Questions/dp/0525537112/ref=sr_1_25?qid=1680261260&sr=8-25&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Riverhead Books',
#  'ranking': [],
#  'rating': '4.8',
#  'rating_breakdown': ['1', '1', '3', '13', '83'],
#  'review_count': '2,276',
#  'title': 'What If? 2: Additional Serious Scientific Answers to Absurd '
#           'Hypothetical Questions'}
# {'_id': ObjectId('642777dffae5a69279b83fe6'),
#  'author': 'Quentin Tarantino  | Nov 1, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/81TrZAPVcCL._AC_UY218_.jpg',
#  'prices': {'Audio': '$33.27',
#             'Audiobook': '$0.00',
#             'Hardcover': '$21.86',
#             'Kindle': '$15.99',
#             'Paperback': '$21.99'},
#  'product_link': '/Cinema-Speculation-Quentin-Tarantino/dp/0063112582/ref=sr_1_24?qid=1680261260&sr=8-24&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Harper',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['1', '2', '6', '20', '70'],
#  'review_count': '1,250',
#  'title': 'Cinema Speculation'}
# {'_id': ObjectId('642777dffae5a69279b83fe7'),
#  'author': 'Neil deGrasse Tyson and Macmillan Audio',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/913Ow4kBrhL._AC_UY218_.jpg',
#  'prices': {'Audio': '$29.99',
#             'Audiobook': '$0.00',
#             'Hardcover': '$15.43',
#             'Kindle': '$14.99',
#             'Paperback': '$28.12'},
#  'product_link': '/Starry-Messenger-Cosmic-Perspectives-Civilization/dp/B09Q7Y4GL5/ref=sr_1_21?qid=1680261260&sr=8-21&srs=17296221011',
#  'publish_date': 'September 20, 2022',
#  'publisher': 'Macmillan Audio',
#  'ranking': ['#824 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#1 in Science Essays & Commentary (Books)',
#              '#2 in Physics (Audible Books & Originals)',
#              '#2 in Astrophysics & Space Science (Books)'],
#  'rating': '4.7',
#  'rating_breakdown': ['1', '1', '4', '14', '79'],
#  'review_count': '2,676',
#  'title': 'Starry Messenger: Cosmic Perspectives on Civilization'}
# {'_id': ObjectId('642777dffae5a69279b83fe8'),
#  'author': 'Viola Davis and HarperAudio',
#  'image': 'https://m.media-amazon.com/images/I/914wvTbNAbL._AC_UY218_.jpg',
#  'prices': {'Audio': '$33.27',
#             'Audiobook': '$0.00',
#             'Hardcover': '$18.48',
#             'Kindle': '$14.99',
#             'Paperback': '$13.48'},
#  'product_link': '/Audible-Finding-Me-A-Memoir/dp/B09F56PHTF/ref=sr_1_11?qid=1680261196&sr=8-11&srs=17296221011',
#  'publish_date': 'April 26, 2022',
#  'publisher': 'HarperAudio',
#  'ranking': ['#47 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#1 in Self-Esteem (Audible Books & Originals)',
#              "#2 in Women's Biographies",
#              '#2 in Biographies of Women'],
#  'rating': '4.8',
#  'rating_breakdown': ['1', '1', '3', '9', '87'],
#  'review_count': '15,546',
#  'title': 'Finding Me: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b83fe9'),
#  'author': 'Shel Van Pelt, Marin Ireland, et al.',
#  'image': 'https://m.media-amazon.com/images/I/91jbLYiK43L._AC_UY218_.jpg',
#  'prices': {'Audio': '$33.27',
#             'Audiobook': '$0.00',
#             'Hardcover': '$18.05',
#             'Kindle': '$14.99',
#             'Paperback': '$15.19'},
#  'product_link': '/Remarkably-Bright-Creatures-A-Novel/dp/B09DTGQHKJ/ref=sr_1_4?qid=1680261196&sr=8-4&srs=17296221011',
#  'publish_date': 'May 3, 2022',
#  'publisher': 'HarperAudio',
#  'ranking': ['#3 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#1 in Mysteries (Audible Books & Originals)',
#              '#1 in Literary Fiction (Books)',
#              '#1 in Animal Fiction (Audible Books & Originals)'],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '5', '22', '71'],
#  'review_count': '21,857',
#  'title': 'Remarkably Bright Creatures: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fea'),
#  'author': 'Nita Prose, Lauren Ambrose, et al.',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/71UlTs6v9UL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$14.74',
#             'Kindle': '$14.99',
#             'Paperback': '$10.00'},
#  'product_link': '/Audible-The-Maid-A-Novel/dp/B09FYHXPBH/ref=sr_1_30?qid=1680261260&sr=8-30&srs=17296221011',
#  'publish_date': 'January 4, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#97 in Audible Books & Originals (See Top 100 in Audible Books & '
#              'Originals)',
#              '#1 in Cozy Mysteries (Audible Books & Originals)',
#              '#2 in Cozy Mysteries (Books)',
#              '#3 in Domestic Thrillers (Audible Books & Originals)'],
#  'rating': '4.2',
#  'rating_breakdown': ['2', '3', '13', '34', '48'],
#  'review_count': '64,343',
#  'title': 'The Maid: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83feb'),
#  'author': 'John Boyne  | Nov 29, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/91ufGHoA9kL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$24.33',
#             'Kindle': '$14.99',
#             'Paperback': '$34.58'},
#  'product_link': '/All-Broken-Places-John-Boyne-ebook/dp/B0B14GBSYH/ref=sr_1_28?qid=1680261260&sr=8-28&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Pamela Dorman Books',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '4', '21', '73'],
#  'review_count': '6,196',
#  'title': 'All the Broken Places: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fec'),
#  'author': 'Siddhartha Mukherjee  | Oct 25, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/81pZkGGlbjL._AC_UY218_.jpg',
#  'prices': {'Audio': '$37.66',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.89',
#             'Kindle': '$16.99',
#             'Paperback': '$21.00'},
#  'product_link': '/Song-Cell-Exploration-Medicine-Human/dp/1982117354/ref=sr_1_20?qid=1680261260&sr=8-20&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Scribner',
#  'ranking': [],
#  'rating': '4.7',
#  'rating_breakdown': ['1', '1', '5', '16', '77'],
#  'review_count': '1,282',
#  'title': 'The Song of the Cell: An Exploration of Medicine and the New Human'}
# {'_id': ObjectId('642777dffae5a69279b83fed'),
#  'author': 'Deanna Raybourn  | Sep 6, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/71FyoSti2xL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$20.49',
#             'Kindle': '$14.99',
#             'Paperback': '$11.63'},
#  'product_link': '/Killers-Certain-Age-Deanna-Raybourn-ebook/dp/B09N6VX4K7/ref=sr_1_31?qid=1680261260&sr=8-31&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Berkley',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['1', '2', '11', '32', '54'],
#  'review_count': '4,470',
#  'title': 'Killers of a Certain Age'}
# {'_id': ObjectId('642777dffae5a69279b83fee'),
#  'author': 'Temple Grandin PhD | Oct 11, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/61J+ySs3bXL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$20.42',
#             'Kindle': '$15.99',
#             'Paperback': '$16.24'},
#  'product_link': '/Visual-Thinking-Pictures-Patterns-Abstractions/dp/0593418360/ref=sr_1_32?qid=1680261260&sr=8-32&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Riverhead Books',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '4', '7', '13', '74'],
#  'review_count': '243',
#  'title': 'Visual Thinking: The Hidden Gifts of People Who Think in Pictures, '
#           'Patterns, and Abstractions'}
# {'_id': ObjectId('642777dffae5a69279b83fef'),
#  'author': 'Dolen Perkins-Valdez, Lauren J. Daggett, et al.',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/81iT24wD0ML._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$14.11',
#             'Kindle': '$13.99',
#             'Paperback': '$17.00'},
#  'product_link': '/Take-My-Hand/dp/B09B2R8J5G/ref=sr_1_27?qid=1680261260&sr=8-27&srs=17296221011',
#  'publish_date': 'April 12, 2022',
#  'publisher': 'Penguin Audio',
#  'ranking': ['#1,425 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#10 in Black & African American Historical Fiction (Books)',
#              '#23 in African American Literature',
#              '#83 in Historical Fiction (Audible Books & Originals)'],
#  'rating': '4.5',
#  'rating_breakdown': ['1', '1', '6', '28', '64'],
#  'review_count': '5,212',
#  'title': 'Take My Hand'}
# {'_id': ObjectId('642777dffae5a69279b83ff0'),
#  'author': 'Ab Jimenez  | Apr 19, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71RBQViFfPL._AC_UY218_.jpg',
#  'prices': {'Audio': '$31.70',
#             'Audiobook': '$0.00',
#             'Kindle': '$10.99',
#             'Library': '$16.89',
#             'Paperback': '$9.99'},
#  'product_link': '/Part-Your-World-Abby-Jimenez/dp/1538704374/ref=sr_1_33?qid=1680261323&sr=8-33&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Forever',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['0', '1', '7', '26', '66'],
#  'review_count': '8,308',
#  'title': 'Part of Your World'}
# {'_id': ObjectId('642777dffae5a69279b83ff1'),
#  'author': 'Jonathan Freedland  | Oct 18, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/814h-ay5h4L._AC_UY218_.jpg',
#  'prices': {'Audio': '$31.61',
#             'Audiobook': '$0.00',
#             'Hardcover': '$26.09',
#             'Kindle': '$14.99',
#             'Paperback': '$17.99'},
#  'product_link': '/Escape-Artist-Broke-Auschwitz-World-ebook/dp/B09QGSNB53/ref=sr_1_29?qid=1680261260&sr=8-29&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Harper',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '5', '25', '69'],
#  'review_count': '3,360',
#  'title': 'The Escape Artist: The Man Who Broke Out of Auschwitz to Warn the '
#           'World'}
# {'_id': ObjectId('642777dffae5a69279b83ff2'),
#  'author': 'Heather Gudenkauf  | Jan 25, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81U4zD8QMsL._AC_UY218_.jpg',
#  'prices': {'Audio': '$31.44',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.99',
#             'Kindle': '$12.99',
#             'Paperback': '$12.49'},
#  'product_link': '/Overnight-Guest-Novel-Heather-Gudenkauf-ebook/dp/B08ZSQLZBS/ref=sr_1_35?qid=1680261323&sr=8-35&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Park Row',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '2', '11', '33', '53'],
#  'review_count': '7,245',
#  'title': 'The Overnight Guest: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83ff3'),
#  'author': 'Dani Shapiro  | Oct 18, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71YtiahbLyL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$18.99',
#             'Kindle': '$14.99',
#             'Paperback': '$27.44'},
#  'product_link': '/Signal-Fires-novel-Dani-Shapiro-ebook/dp/B09Q8FNM11/ref=sr_1_36?qid=1680261323&sr=8-36&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Knopf',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['2', '3', '12', '30', '52'],
#  'review_count': '2,725',
#  'title': 'Signal Fires: A novel'}
# {'_id': ObjectId('642777dffae5a69279b83ff4'),
#  'author': 'Lucy Foley, Clare Corbett, et al.',
#  'image': 'https://m.media-amazon.com/images/I/911V88A7KeL._AC_UY218_.jpg',
#  'prices': {'Audio': '—',
#             'Audiobook': '$0.00',
#             'Hardcover': '$15.88',
#             'Kindle': '$12.99',
#             'Paperback': '$14.24'},
#  'product_link': '/The-Paris-Apartment-A-Novel/dp/B0997FBQFJ/ref=sr_1_34?qid=1680261323&sr=8-34&srs=17296221011',
#  'publish_date': 'February 22, 2022',
#  'publisher': 'HarperAudio',
#  'ranking': ['#196 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#2 in Women Sleuth Mysteries',
#              '#9 in Women Sleuths (Books)',
#              '#10 in Psychological Thrillers (Audible Books & Originals)'],
#  'rating': '4.1',
#  'rating_breakdown': ['2', '4', '18', '36', '39'],
#  'review_count': '41,133',
#  'title': 'The Paris Apartment: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83ff5'),
#  'author': 'Sabaa Tahir  | Mar 7, 2023',
#  'image': 'https://m.media-amazon.com/images/I/913SV5CtsVL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$10.49',
#             'Kindle': '$8.99',
#             'Paperback': '$11.69'},
#  'product_link': '/All-My-Rage-Sabaa-Tahir/dp/0593202368/ref=sr_1_37?qid=1680261323&sr=8-37&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Razorbill',
#  'ranking': [],
#  'rating': '4.7',
#  'rating_breakdown': ['1', '1', '4', '18', '76'],
#  'review_count': '1,609',
#  'title': 'All My Rage: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83ff6'),
#  'author': 'Book 3 of 3: Beartown   |  Fredrik Backman, Marin Ireland, et al.',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/911q2NsUlDL._AC_UY218_.jpg',
#  'prices': {'Audio': '$43.73',
#             'Audiobook': '$0.00',
#             'Hardcover': '$14.99',
#             'Kindle': '$14.99',
#             'Paperback': '$19.99'},
#  'product_link': '/Audible-The-Winners-A-Novel/dp/B09V8GLPTK/ref=sr_1_26?qid=1680261260&sr=8-26&srs=17296221011',
#  'publish_date': 'September 27, 2022',
#  'publisher': 'Simon & Schuster Audio',
#  'ranking': ['#1,004 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#3 in Sports Fiction (Audible Books & Originals)',
#              '#6 in Small Town & Rural Fiction (Audible Books & Originals)',
#              '#21 in Small Town & Rural Fiction (Books)'],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '6', '19', '73'],
#  'review_count': '7,592',
#  'title': 'The Winners: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83ff7'),
#  'author': 'Douglas Stuart  | Mar 21, 2023',
#  'image': 'https://m.media-amazon.com/images/I/71zJL1N2sgL._AC_UY218_.jpg',
#  'prices': {'Hardcover': '$14.89', 'Kindle': '$9.45', 'Paperback': '$16.20'},
#  'product_link': '/Young-Mungo-Douglas-Stuart/dp/0802162126/ref=sr_1_39?qid=1680261323&sr=8-39&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Grove Press',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['2', '2', '7', '21', '69'],
#  'review_count': '1,739',
#  'title': 'Young Mungo'}
# {'_id': ObjectId('642777dffae5a69279b83ff8'),
#  'author': 'Johann Hari  | Jan 24, 2023',
#  'image': 'https://m.media-amazon.com/images/I/71Y85lJdsHL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$20.99',
#             'Kindle': '$14.99',
#             'Paperback': '$16.20'},
#  'product_link': '/Stolen-Focus-Attention-Think-Deeply/dp/0593138538/ref=sr_1_38?qid=1680261323&sr=8-38&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Crown',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['2', '3', '9', '23', '64'],
#  'review_count': '4,443',
#  'title': "Stolen Focus: Why You Can't Pay Attention--and How to Think Deeply "
#           'Again'}
# {'_id': ObjectId('642777dffae5a69279b83ff9'),
#  'author': 'Jessi Klein  | Apr 26, 2022',
#  'image': 'https://m.media-amazon.com/images/I/714vv1T7weL._AC_UY218_.jpg',
#  'prices': {'Audio': '$23.45',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.65',
#             'Kindle': '$11.99',
#             'Paperback': '$18.99'},
#  'product_link': '/Ill-Show-Myself-Out-Motherhood-ebook/dp/B0995Y2YGR/ref=sr_1_41?qid=1680261323&sr=8-41&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Harper',
#  'ranking': [],
#  'rating': '4.2',
#  'rating_breakdown': ['3', '5', '14', '26', '52'],
#  'review_count': '732',
#  'title': "I'll Show Myself Out: Essays on Midlife and Motherhood"}
# {'_id': ObjectId('642777dffae5a69279b83ffa'),
#  'author': 'Katherine Center, Patti Murin, et al.',
#  'image': 'https://m.media-amazon.com/images/I/81cABsOmCaL._AC_UY218_.jpg',
#  'prices': {'Audio': '$39.99',
#             'Audiobook': '$0.00',
#             'Hardcover': '$15.99',
#             'Kindle': '$14.99',
#             'Paperback': '$17.00'},
#  'product_link': '/The-Bodyguard-A-Novel/dp/B09GCMPC93/ref=sr_1_40?qid=1680261323&sr=8-40&srs=17296221011',
#  'publish_date': 'July 19, 2022',
#  'publisher': 'Macmillan Audio',
#  'ranking': ['#1,309 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#26 in Romantic Comedy (Audible Books & Originals)',
#              '#46 in Family Life Fiction (Audible Books & Originals)',
#              "#86 in Women's Fiction (Audible Books & Originals)"],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '2', '12', '34', '51'],
#  'review_count': '7,343',
#  'title': 'The Bodyguard: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83ffb'),
#  'author': 'Nina de Gramont  | Feb 1, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71PSosAox1L._AC_UY218_.jpg',
#  'prices': {'Audio': '$39.99',
#             'Audiobook': '$0.00',
#             'Hardcover': '$14.69',
#             'Kindle': '$11.99',
#             'Paperback': '$17.99'},
#  'product_link': '/Christie-Affair-Novel-Nina-Gramont-ebook/dp/B092T9DMJ5/ref=sr_1_44?qid=1680261323&sr=8-44&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': "St. Martin's Press",
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '3', '14', '32', '50'],
#  'review_count': '9,364',
#  'title': 'The Christie Affair: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83ffc'),
#  'author': 'Stephanie Foo and Random House Audio',
#  'image': 'https://m.media-amazon.com/images/I/811k+wApPPL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$20.49',
#             'Kindle': '$12.99',
#             'Paperback': '$16.20'},
#  'product_link': '/What-My-Bones-Know-Healing/dp/B0977R5NZ4/ref=sr_1_43?qid=1680261323&sr=8-43&srs=17296221011',
#  'publish_date': 'February 22, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#629 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#5 in PTSD',
#              '#11 in Popular Psychology Pathologies',
#              '#12 in Post-traumatic Stress Disorder'],
#  'rating': '4.7',
#  'rating_breakdown': ['1', '1', '5', '16', '77'],
#  'review_count': '2,205',
#  'title': 'What My Bones Know: A Memoir of Healing from Complex Trauma'}
# {'_id': ObjectId('642777dffae5a69279b83ffd'),
#  'author': 'Margaret A. Burnham  | Sep 27, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71Eat8UjvHL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$15.27',
#             'Kindle': '$9.66',
#             'Paperback': '$19.95'},
#  'product_link': '/Hands-Now-Known-Crows-Executioners/dp/0393867854/ref=sr_1_46?qid=1680261323&sr=8-46&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'W. W. Norton & Company',
#  'ranking': [],
#  'rating': '4.7',
#  'rating_breakdown': ['0', '2', '4', '20', '74'],
#  'review_count': '85',
#  'title': "By Hands Now Known: Jim Crow's Legal Executioners"}
# {'_id': ObjectId('642777dffae5a69279b83ffe'),
#  'author': 'Kelly Rimmer  | Jun 28, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81XWMjUuzML._AC_UY218_.jpg',
#  'prices': {'Audio': '$33.27',
#             'Audiobook': '$0.00',
#             'Hardcover': '$23.49',
#             'Kindle': '$14.99',
#             'Paperback': '$13.84',
#             'Spiral-bound': '$31.14'},
#  'product_link': '/German-Wife-Novel-Kelly-Rimmer-ebook/dp/B09FGT2V4F/ref=sr_1_45?qid=1680261323&sr=8-45&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Graydon House',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['1', '1', '6', '26', '66'],
#  'review_count': '3,260',
#  'title': 'The German Wife: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b83fff'),
#  'author': 'Leila Mottley, Joniece Abbott-Pratt, et al.',
#  'image': 'https://m.media-amazon.com/images/I/81gnY73kmGL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$16.99',
#             'Kindle': '$14.99',
#             'Paperback': '$17.00'},
#  'product_link': '/Audible-Nightcrawling-A-Novel/dp/B09GPYTKWX/ref=sr_1_50?qid=1680261389&sr=8-50&srs=17296221011',
#  'publish_date': 'June 7, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#5,865 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#9 in Urban Fiction (Audible Books & Originals)',
#              '#50 in Fiction Urban Life',
#              '#164 in Family Life Fiction (Audible Books & Originals)'],
#  'rating': '4.4',
#  'rating_breakdown': ['1', '2', '11', '26', '59'],
#  'review_count': '3,950',
#  'title': 'Nightcrawling: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84000'),
#  'author': 'Book 1 of 2: The City   |  Don Winslow  | Apr 26, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71kmzOiW16L._AC_UY218_.jpg',
#  'prices': {'Audio': '$34.86',
#             'Audiobook': '$0.00',
#             'Hardcover': '$14.99',
#             'Kindle': '$14.99',
#             'Paperback': '$16.33'},
#  'product_link': '/City-Fire-Novel-Don-Winslow-ebook/dp/B09131XKCQ/ref=sr_1_51?qid=1680261389&sr=8-51&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'William Morrow',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['2', '3', '11', '30', '54'],
#  'review_count': '7,650',
#  'title': 'City on Fire: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84001'),
#  'author': 'Kwame Alexander  | Sep 27, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81peOOwSM6L._AC_UY218_.jpg',
#  'prices': {'Audio': '$32.55',
#             'Audiobook': '$0.00',
#             'Hardcover': '$10.47',
#             'Kindle': '$9.99'},
#  'product_link': '/Door-No-Return-Kwame-Alexander/dp/0316441864/ref=sr_1_47?qid=1680261323&sr=8-47&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Little, Brown Books for Young Readers',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '8', '14', '76'],
#  'review_count': '137',
#  'title': 'The Door of No Return'}
# {'_id': ObjectId('642777dffae5a69279b84002'),
#  'author': 'Tara M. Stringfellow  | Apr 5, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81jEc6olAeL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$14.11',
#             'Kindle': '$13.99',
#             'Paperback': '$11.69'},
#  'product_link': '/Memphis-Novel-Tara-M-Stringfellow-ebook/dp/B093YSLSJD/ref=sr_1_53?qid=1680261389&sr=8-53&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'The Dial Press',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['1', '2', '8', '26', '63'],
#  'review_count': '3,551',
#  'title': 'Memphis: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84003'),
#  'author': 'Joanna Quinn  | Oct 4, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81DE33NaPNL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$15.22',
#             'Kindle': '$14.99',
#             'Paperback': '$24.65'},
#  'product_link': '/Whalebone-Theatre-novel-Joanna-Quinn-ebook/dp/B09LHBD39F/ref=sr_1_49?qid=1680261389&sr=8-49&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Knopf',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['2', '3', '9', '27', '59'],
#  'review_count': '1,249',
#  'title': 'The Whalebone Theatre: A novel'}
# {'_id': ObjectId('642777dffae5a69279b84004'),
#  'author': 'Candice Millard, Paul Michael, et al.',
#  'image': 'https://m.media-amazon.com/images/I/81HUzpIdN9L._AC_UY218_.jpg',
#  'prices': {'Audio': '$31.22',
#             'Audiobook': '$0.00',
#             'Hardcover': '$18.00',
#             'Kindle': '$14.99',
#             'Paperback': '$18.00'},
#  'product_link': '/River-Gods-Genius-Courage-Betrayal/dp/B09FFTM2Y8/ref=sr_1_42?qid=1680261323&sr=8-42&srs=17296221011',
#  'publish_date': 'May 17, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#4,842 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#3 in Historical African Biographies (Books)',
#              '#4 in Expeditions & Discoveries',
#              '#5 in African History (Audible Books & Originals)'],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '2', '11', '32', '53'],
#  'review_count': '2,571',
#  'title': 'River of the Gods: Genius, Courage, and Betrayal in the Search for '
#           'the Source of the Nile'}
# {'_id': ObjectId('642777dffae5a69279b84005'),
#  'author': 'Charmaine Wilkerson, Lynnette R. Freeman, et al.',
#  'image': 'https://m.media-amazon.com/images/I/81QtLzgF1RL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$16.99',
#             'Kindle': '$13.99',
#             'Paperback': '$12.75'},
#  'product_link': '/Audible-Black-Cake-A-Novel/dp/B09B2NNXMG/ref=sr_1_52?qid=1680261389&sr=8-52&srs=17296221011',
#  'publish_date': 'February 1, 2022',
#  'publisher': 'Random House Audio',
#  'ranking': ['#466 in Audible Books & Originals (See Top 100 in Audible Books '
#              '& Originals)',
#              '#9 in Coming of Age Fiction (Audible Books & Originals)',
#              '#18 in Family Life Fiction (Audible Books & Originals)',
#              '#48 in Coming of Age Fiction (Books)'],
#  'rating': '4.4',
#  'rating_breakdown': ['1', '2', '11', '30', '56'],
#  'review_count': '14,655',
#  'title': 'Black Cake: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84006'),
#  'author': 'Sarah Adams  | Sep 20, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71877Z+S0nL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00', 'Kindle': '$7.99', 'Paperback': '$12.91'},
#  'product_link': '/When-Rome-Novel-Sarah-Adams-ebook/dp/B09QJM783S/ref=sr_1_54?qid=1680261389&sr=8-54&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Dell',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '3', '14', '32', '50'],
#  'review_count': '2,446',
#  'title': 'When in Rome: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84007'),
#  'author': 'Galit Atlas  | Jan 25, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81wxhBTc+dL._AC_UY218_.jpg',
#  'prices': {'Audio': '$31.70',
#             'Audiobook': '$0.00',
#             'Hardcover': '$22.99',
#             'Kindle': '$13.99',
#             'Paperback': '$18.99'},
#  'product_link': '/Emotional-Inheritance-Therapist-Patients-Legacy-ebook/dp/B093ZPV3RG/ref=sr_1_56?qid=1680261389&sr=8-56&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Little, Brown Spark',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['2', '2', '5', '19', '71'],
#  'review_count': '658',
#  'title': 'Emotional Inheritance: A Therapist, Her Patients, and the Legacy of '
#           'Trauma'}
# {'_id': ObjectId('642777dffae5a69279b84008'),
#  'author': 'Jann  Wenner  | Sep 13, 2022',
#  'image': 'https://m.media-amazon.com/images/I/814YCGJPGgL._AC_UY218_.jpg',
#  'prices': {'Audio': '$55.00',
#             'Audiobook': '$0.00',
#             'Hardcover': '$18.29',
#             'Kindle': '$16.99',
#             'Paperback': '$16.99'},
#  'product_link': '/Like-Rolling-Stone-Jann-Wenner-ebook/dp/B09PL5JG93/ref=sr_1_55?qid=1680261389&sr=8-55&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Little, Brown and Company',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['4', '4', '9', '22', '62'],
#  'review_count': '1,178',
#  'title': 'Like a Rolling Stone: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b84009'),
#  'author': 'Kevin Wilson, Ginnifer Goodwin, et al.',
#  'image': 'https://m.media-amazon.com/images/I/912y9mvq6uL._AC_UY218_.jpg',
#  'prices': {'Audio': '$29.30',
#             'Audiobook': '$0.00',
#             'Hardcover': '$18.39',
#             'Kindle': '$14.99',
#             'Paperback': '$18.99'},
#  'product_link': '/Now-Not-Time-Panic-Novel/dp/B09TWRP839/ref=sr_1_57?qid=1680261389&sr=8-57&srs=17296221011',
#  'publish_date': 'November 8, 2022',
#  'publisher': 'HarperAudio',
#  'ranking': ['#4,762 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#8 in Southern United States Literature',
#              '#25 in Southern Fiction',
#              '#75 in Coming of Age Fiction (Audible Books & Originals)'],
#  'rating': '4.0',
#  'rating_breakdown': ['2', '5', '21', '38', '34'],
#  'review_count': '1,761',
#  'title': 'Now Is Not the Time to Panic: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b8400a'),
#  'author': 'Paul Holes, Robin Ga Fisher, et al.',
#  'image': 'https://m.media-amazon.com/images/I/9109ZHfsJyL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$14.25',
#             'Kindle': '$14.99',
#             'Paperback': '$18.00'},
#  'product_link': '/Unmasked-Life-Solving-Americas-Cases/dp/B094DNHM3N/ref=sr_1_58?qid=1680261389&sr=8-58&srs=17296221011',
#  'publish_date': 'April 26, 2022',
#  'publisher': 'Macmillan Audio',
#  'ranking': ['#3,072 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#6 in Serial Killers True Crime',
#              '#10 in Law Enforcement Biographies',
#              '#15 in Serial Killers True Accounts'],
#  'rating': '4.5',
#  'rating_breakdown': ['1', '2', '8', '22', '68'],
#  'review_count': '2,841',
#  'title': "Unmasked: My Life Solving America's Cold Cases"}
# {'_id': ObjectId('642777dffae5a69279b8400b'),
#  'author': 'Book 1 of 2: The City   |  Don Winslow  | Apr 26, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71kmzOiW16L._AC_UY218_.jpg',
#  'prices': {'Audio': '$34.86',
#             'Audiobook': '$0.00',
#             'Hardcover': '$14.99',
#             'Kindle': '$14.99',
#             'Paperback': '$16.33'},
#  'product_link': '/City-Fire-Novel-Don-Winslow-ebook/dp/B09131XKCQ/ref=sr_1_48?qid=1680261323&sr=8-48&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'William Morrow',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['2', '3', '11', '30', '54'],
#  'review_count': '7,650',
#  'title': 'City on Fire: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b8400c'),
#  'author': 'Ben Macintyre  | Sep 13, 2022',
#  'image': 'https://m.media-amazon.com/images/I/91KuSJemvGL._AC_UY218_.jpg',
#  'prices': {'Audio': '$33.53',
#             'Audiobook': '$0.00',
#             'Hardcover': '$17.26',
#             'Kindle': '$13.99',
#             'Paperback': '$26.91'},
#  'product_link': '/Prisoners-Castle-Survival-Colditz-Fortress-ebook/dp/B09NLPP1CP/ref=sr_1_59?qid=1680261389&sr=8-59&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Crown',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '1', '6', '24', '68'],
#  'review_count': '1,695',
#  'title': 'Prisoners of the Castle: An Epic Story of Survival and Escape from '
#           "Colditz, the Nazis' Fortress Prison"}
# {'_id': ObjectId('642777dffae5a69279b8400d'),
#  'author': 'Jennifer Hillier  | Jul 19, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71T4RReoaML._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$17.29',
#             'Kindle': '$14.99',
#             'Paperback': '$18.00'},
#  'product_link': '/Things-We-Do-Dark-Novel-ebook/dp/B09CNF5JK3/ref=sr_1_61?qid=1680261389&sr=8-61&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Minotaur Books',
#  'ranking': [],
#  'rating': '4.2',
#  'rating_breakdown': ['1', '2', '14', '39', '43'],
#  'review_count': '5,309',
#  'title': 'Things We Do in the Dark: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b8400e'),
#  'author': 'Molly Shannon, Sean Wilsey, et al.',
#  'image': 'https://m.media-amazon.com/images/I/71dNe7sxbQL._AC_UY218_.jpg',
#  'prices': {'Audio': '$29.77',
#             'Audiobook': '$0.00',
#             'Hardcover': '$14.93',
#             'Kindle': '$14.99',
#             'Paperback': '$19.99'},
#  'product_link': '/Audible-Hello-Molly-A-Memoir/dp/B09BBPWR7P/ref=sr_1_60?qid=1680261389&sr=8-60&srs=17296221011',
#  'publish_date': 'April 12, 2022',
#  'publisher': 'HarperAudio',
#  'ranking': ['#1,497 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
# ...
#  'product_link': '/Tanqueray-Brandon-Stanton/dp/1250278279/ref=sr_1_80?qid=1680261489&sr=8-80&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': "St. Martin's Press",
#  'ranking': [],
#  'rating': '4.8',
#  'rating_breakdown': ['1', '1', '4', '10', '84'],
#  'review_count': '2,252',
#  'title': 'Tanqueray'}
# {'_id': ObjectId('642777dffae5a69279b8401f'),
#  'author': 'Mark Bergen  | Sep 6, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81SA3p4+x5L._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$20.49',
#             'Kindle': '$15.99',
#             'Paperback': '$24.00'},
#  'product_link': '/Like-Comment-Subscribe-YouTubes-Domination/dp/0593296346/ref=sr_1_81?qid=1680261563&sr=8-81&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Viking',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['1', '3', '13', '26', '57'],
#  'review_count': '126',
#  'title': "Like, Comment, Subscribe: Inside YouTube's Chaotic Rise to World "
#           'Domination'}
# {'_id': ObjectId('642777dffae5a69279b84020'),
#  'author': 'Emi Nietfeld  | Aug 2, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81m4dJ8d9-L._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00', 'Hardcover': '$10.28', 'Kindle': '$14.99'},
#  'product_link': '/Acceptance-Memoir-Emi-Nietfeld-ebook/dp/B09KXS5KKL/ref=sr_1_79?qid=1680261489&sr=8-79&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Penguin Press',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['2', '1', '8', '22', '66'],
#  'review_count': '439',
#  'title': 'Acceptance: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b84021'),
#  'author': 'Sophie Irwin  | Jul 12, 2022',
#  'image': 'https://m.media-amazon.com/images/I/91P3C3+rx1L._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$16.99',
#             'Kindle': '$14.99',
#             'Paperback': '$17.00'},
#  'product_link': '/Ladys-Guide-Fortune-Hunting-Novel-ebook/dp/B09JB7L18C/ref=sr_1_64?qid=1680261389&sr=8-64&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Pamela Dorman Books',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '3', '13', '35', '49'],
#  'review_count': '2,386',
#  'title': "A Lady's Guide to Fortune-Hunting: A Novel"}
# {'_id': ObjectId('642777dffae5a69279b84022'),
#  'author': 'Tom Mustill  | Sep 6, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81bRujOgt7L._AC_UY218_.jpg',
#  'prices': {'Audio': '$26.74',
#             'Audiobook': '$0.00',
#             'Hardcover': '$24.99',
#             'Kindle': '$14.99',
#             'Paperback': '$18.99'},
#  'product_link': '/How-Speak-Whale-Voyage-Communication-ebook/dp/B09PL5H8TT/ref=sr_1_77?qid=1680261489&sr=8-77&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Grand Central Publishing',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['4', '0', '9', '17', '70'],
#  'review_count': '93',
#  'title': 'How to Speak Whale: A Voyage into the Future of Animal '
#           'Communication'}
# {'_id': ObjectId('642777dffae5a69279b84023'),
#  'author': 'Book 3 of 3: Boyfriend Project   |  Farrah Rochon  | Aug 2, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71Bi-0uqa5L._AC_UY218_.jpg',
#  'prices': {'Audio': '$25.00',
#             'Audiobook': '$0.00',
#             'Kindle': '$3.99',
#             'Paperback': '$12.00'},
#  'product_link': '/Hookup-Plan-Farrah-Rochon-ebook/dp/B09N3F3WV5/ref=sr_1_82?qid=1680261563&sr=8-82&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Forever',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['0', '1', '9', '34', '56'],
#  'review_count': '658',
#  'title': 'The Hookup Plan'}
# {'_id': ObjectId('642777dffae5a69279b84024'),
#  'author': 'Neal Thompson  | Feb 22, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81o0F4b9PdL._AC_UY218_.jpg',
#  'prices': {'Audio': '$28.00',
#             'Audiobook': '$0.00',
#             'Hardcover': '$19.85',
#             'Kindle': '$12.99',
#             'Paperback': '$21.99'},
#  'product_link': '/First-Kennedys-Humble-American-Dynasty-ebook/dp/B08NWRR59W/ref=sr_1_86?qid=1680261563&sr=8-86&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Mariner Books',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['4', '3', '11', '26', '57'],
#  'review_count': '397',
#  'title': 'The First Kennedys: The Humble Roots of an American Dynasty'}
# {'_id': ObjectId('642777dffae5a69279b84025'),
#  'author': 'Jennifer E. Smith  | Mar 1, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71Ib87d4ARL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$15.49',
#             'Kindle': '$11.99',
#             'Paperback': '$17.00'},
#  'product_link': '/Unsinkable-Greta-James-Novel-ebook/dp/B096D6BCTF/ref=sr_1_85?qid=1680261563&sr=8-85&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Ballantine Books',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '3', '13', '37', '47'],
#  'review_count': '2,349',
#  'title': 'The Unsinkable Greta James: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84026'),
#  'author': 'Robert Samuels  and Toluse Olorunnipa  | May 17, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71KWFLSchiL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$23.99',
#             'Kindle': '$14.99',
#             'Paperback': '$23.06'},
#  'product_link': '/His-Name-George-Floyd-Struggle/dp/0593490614/ref=sr_1_84?qid=1680261563&sr=8-84&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Viking',
#  'ranking': [],
#  'rating': '4.7',
#  'rating_breakdown': ['2', '3', '4', '9', '83'],
#  'review_count': '218',
#  'title': "His Name Is George Floyd: One Man's Life and the Struggle for "
#           'Racial Justice'}
# {'_id': ObjectId('642777dffae5a69279b84027'),
#  'author': 'Michael Smith  and Jonathan Franklin  | Jun 21, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81sNPbR+VwL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$24.49',
#             'Kindle': '$14.99',
#             'Paperback': '$25.75'},
#  'product_link': '/Cabin-Fever-Harrowing-Journey-Pandemic-ebook/dp/B09GW1HFDH/ref=sr_1_89?qid=1680261563&sr=8-89&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Doubleday',
#  'ranking': [],
#  'rating': '4.5',
#  'rating_breakdown': ['1', '2', '7', '26', '64'],
#  'review_count': '530',
#  'title': 'Cabin Fever: The Harrowing Journey of a Cruise Ship at the Dawn of '
#           'a Pandemic'}
# {'_id': ObjectId('642777dffae5a69279b84028'),
#  'author': 'Book 2 of 3: Winner Bakes All   |  Alexis Hall  | Nov 1, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81ChpDzmdjL._AC_UY218_.jpg',
#  'prices': {'Audio': '$28.40',
#             'Audiobook': '$0.00',
#             'Kindle': '$9.99',
#             'Paperback': '$10.23'},
#  'product_link': '/Paris-Daillencourt-About-Crumble-Winner-ebook/dp/B09RWNW6LD/ref=sr_1_91?qid=1680261563&sr=8-91&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Forever',
#  'ranking': [],
#  'rating': '4.1',
#  'rating_breakdown': ['0', '4', '19', '36', '40'],
#  'review_count': '447',
#  'title': 'Paris Daillencourt Is About to Crumble (Winner Bakes All Book 2)'}
# {'_id': ObjectId('642777dffae5a69279b84029'),
#  'author': 'Book 1 of 2: The Ending Fire Trilogy   |  Saara El-Arifi  | Jun '
#            '21, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81fcapAK1sL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$20.99',
#             'Kindle': '$11.99',
#             'Paperback': '$18.00'},
#  'product_link': '/Final-Strife-Saara-El-Arifi-ebook/dp/B09HTH9QC3/ref=sr_1_90?qid=1680261563&sr=8-90&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Del Rey',
#  'ranking': [],
#  'rating': '4.6',
#  'rating_breakdown': ['1', '2', '4', '23', '70'],
#  'review_count': '350',
#  'title': 'The Final Strife: Book One of The Ending Fire Trilogy'}
# {'_id': ObjectId('642777dffae5a69279b8402a'),
#  'author': 'Isabel Kaplan  | Jul 5, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71O2bNw-QSL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$19.23',
#             'Kindle': '$13.99',
#             'Paperback': '$17.26'},
#  'product_link': '/NSFW-Novel-Isabel-Kaplan-ebook/dp/B09C4FV185/ref=sr_1_92?qid=1680261563&sr=8-92&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Henry Holt and Co.',
#  'ranking': [],
#  'rating': '3.7',
#  'rating_breakdown': ['2', '12', '27', '31', '28'],
#  'review_count': '183',
#  'title': 'NSFW: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b8402b'),
#  'author': 'Courtney Maum  | Feb 14, 2023',
#  'image': 'https://m.media-amazon.com/images/I/71JmatnPSPL._AC_UY218_.jpg',
#  'prices': {'Audio': '$31.95',
#             'Audiobook': '$0.00',
#             'Hardcover': '$25.11',
#             'Kindle': '$13.49',
#             'Paperback': '$17.95'},
#  'product_link': '/Year-Horses-Memoir-Courtney-Maum/dp/1953534821/ref=sr_1_94?qid=1680261563&sr=8-94&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Tin House Books',
#  'ranking': [],
#  'rating': '4.1',
#  'rating_breakdown': ['6', '6', '12', '22', '53'],
#  'review_count': '154',
#  'title': 'The Year of the Horses: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b8402c'),
#  'author': 'Lev AC Rosen  | Oct 18, 2022',
#  'image': 'https://m.media-amazon.com/images/I/91R769GgqeL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$25.31',
#             'Kindle': '$13.99',
#             'Paperback': '$17.99'},
#  'product_link': '/Lavender-House-Lev-AC-Rosen-ebook/dp/B09NK7VYGF/ref=sr_1_83?qid=1680261563&sr=8-83&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Forge Books',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['1', '2', '12', '29', '56'],
#  'review_count': '320',
#  'title': 'Lavender House: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b8402d'),
#  'author': 'Catherine Adel West  | Sep 6, 2022',
#  'image': 'https://m.media-amazon.com/images/I/91XHumXWseL._AC_UY218_.jpg',
#  'prices': {'Audio': '$23.52',
#             'Audiobook': '$0.00',
#             'Hardcover': '$15.39',
#             'Kindle': '$13.99',
#             'Paperback': '$16.99'},
#  'product_link': '/Two-Lives-Sara-Novel-ebook/dp/B09QQMXGYK/ref=sr_1_87?qid=1680261563&sr=8-87&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Park Row',
#  'ranking': [],
#  'rating': '4.2',
#  'rating_breakdown': ['2', '2', '14', '35', '47'],
#  'review_count': '198',
#  'title': 'The Two Lives of Sara: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b8402e'),
#  'author': 'Bella Mackie  | Aug 2, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81HeVWjFY7L._AC_UY218_.jpg',
#  'prices': {'Audio': '$25.30',
#             'Audiobook': '$0.00',
#             'Hardcover': '$18.28',
#             'Kindle': '$9.99',
#             'Paperback': '$13.50'},
#  'product_link': '/How-Kill-Your-Family-Novel-ebook/dp/B09S3S9K5P/ref=sr_1_96?qid=1680261563&sr=8-96&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'The Overlook Press',
#  'ranking': [],
#  'rating': '4.0',
#  'rating_breakdown': ['3', '6', '18', '29', '43'],
#  'review_count': '20,610',
#  'title': 'How to Kill Your Family: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b8402f'),
#  'author': 'Reema Patel  | May 10, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/91Biub6GqqL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$15.99',
#             'Kindle': '$13.99',
#             'Paperback': '$18.00'},
#  'product_link': '/Such-Big-Dreams-Reema-Patel-ebook/dp/B09H2NNGZV/ref=sr_1_98?qid=1680261638&sr=8-98&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Ballantine Books',
#  'ranking': [],
#  'rating': '4.3',
#  'rating_breakdown': ['2', '0', '9', '38', '51'],
#  'review_count': '255',
#  'title': 'Such Big Dreams: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84030'),
#  'author': 'Julia Whelan and HarperAudio',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/81CfG7QAs0L._AC_UY218_.jpg',
#  'prices': {'Audio': '$30.90',
#             'Audiobook': '$0.00',
#             'Hardcover': '$19.29',
#             'Kindle': '$8.99',
#             'Paperback': '$14.39'},
#  'product_link': '/Audible-Thank-You-Listening-Novel/dp/B09K4K5LNG/ref=sr_1_97?qid=1680261638&sr=8-97&srs=17296221011',
#  'publish_date': 'August 2, 2022',
#  'publisher': 'HarperAudio',
#  'ranking': ['#1,047 in Audible Books & Originals (See Top 100 in Audible '
#              'Books & Originals)',
#              '#6 in Friendship Fiction (Audible Books & Originals)',
#              '#16 in Friendship Fiction (Books)',
#              '#23 in Romantic Comedy (Audible Books & Originals)'],
#  'rating': '4.3',
#  'rating_breakdown': ['1', '3', '14', '36', '47'],
#  'review_count': '2,189',
#  'title': 'Thank You for Listening: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84031'),
#  'author': 'Danielle Prescod  | Oct 1, 2022',
#  'image': 'https://m.media-amazon.com/images/I/71cVYnvkN9L._AC_UY218_.jpg',
#  'prices': {'Audio': '$13.72',
#             'Audiobook': '$0.00',
#             'Hardcover': '$15.67',
#             'Kindle': '$0.00',
#             'Paperback': '$10.99'},
#  'product_link': '/Token-Black-Girl-Danielle-Prescod-ebook/dp/B09KLLG3L2/ref=sr_1_88?qid=1680261563&sr=8-88&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Little A',
#  'ranking': [],
#  'rating': '4.2',
#  'rating_breakdown': ['2', '4', '15', '29', '50'],
#  'review_count': '3,210',
#  'title': 'Token Black Girl: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b84032'),
#  'author': 'N. Jamiyla Chisholm  | Jun 1, 2022',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/81pIr-oANIL._AC_UY218_.jpg',
#  'prices': {'Audio': '$5.62',
#             'Audiobook': '$0.00',
#             'Hardcover': '$12.70',
#             'Kindle': '$0.00',
#             'Paperback': '$12.26'},
#  'product_link': '/Community-N-Jamiyla-Chisholm-ebook/dp/B0976VRCV1/ref=sr_1_99?qid=1680261638&sr=8-99&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Little A',
#  'ranking': [],
#  'rating': '3.9',
#  'rating_breakdown': ['4', '7', '22', '30', '37'],
#  'review_count': '2,881',
#  'title': 'The Community: A Memoir'}
# {'_id': ObjectId('642777dffae5a69279b84033'),
#  'author': '',
#  'image': 'https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/71yazKQc-rL._AC_UY218_.jpg',
#  'prices': {'Hardcover': '$27.23'},
#  'product_link': '/Book-Meant-be-Novel/dp/1368050395/ref=sr_1_100?qid=1680261638&sr=8-100&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Hyperion Avenue',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['0', '15', '0', '19', '66'],
#  'review_count': '7',
#  'title': 'By the Book-A Meant To Be Novel'}
# {'_id': ObjectId('642777dffae5a69279b84034'),
#  'author': 'Rachel M. Harper  | May 3, 2022',
#  'image': 'https://m.media-amazon.com/images/I/91VEqtaf8YL._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$24.64',
#             'Kindle': '$13.99',
#             'Paperback': '$18.95'},
#  'product_link': '/Other-Mother-Rachel-M-Harper-ebook/dp/B096DH78WQ/ref=sr_1_95?qid=1680261563&sr=8-95&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Counterpoint',
#  'ranking': [],
#  'rating': '4.4',
#  'rating_breakdown': ['2', '3', '9', '31', '55'],
#  'review_count': '398',
#  'title': 'The Other Mother: A Novel'}
# {'_id': ObjectId('642777dffae5a69279b84035'),
#  'author': 'Dan Chaon  | May 24, 2022',
#  'image': 'https://m.media-amazon.com/images/I/81tropLV-RS._AC_UY218_.jpg',
#  'prices': {'Audiobook': '$0.00',
#             'Hardcover': '$16.99',
#             'Kindle': '$14.99',
#             'Paperback': '$17.99'},
#  'product_link': '/Sleepwalk-Novel-Dan-Chaon-ebook/dp/B092T8V4W1/ref=sr_1_93?qid=1680261563&sr=8-93&srs=17296221011',
#  'publish_date': 'Jan 1, 1970',
#  'publisher': 'Henry Holt and Co.',
#  'ranking': [],
#  'rating': '4.0',
#  'rating_breakdown': ['3', '6', '19', '33', '39'],
#  'review_count': '612',
#  'title': 'Sleepwalk: A Novel'}
